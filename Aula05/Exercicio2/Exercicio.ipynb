# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split, learning_curve

# %%
dataset = pd.read_csv('../datasets/Dataset_3Cluster_4features.csv')

# %%
dataset.head()
# Out:
#          V1        V2        V3        V4  V5
# 0  0.762550  0.843568  0.836821  0.904889   1
# 1  0.760337  0.961476  0.760661  0.757853   1
# 2  0.764597  0.796654  0.756289  0.850313   1
# 3  0.692830  0.722283  0.703194  0.702109   1
# 4  0.848631  0.886957  0.859482  0.702199   1

# %%
dataset.describe()
# Out:
#                V1          V2          V3          V4          V5
# count  300.000000  300.000000  300.000000  300.000000  300.000000
# mean     0.566286    0.464751    0.530167    0.638497    2.000000
# std      0.230186    0.261773    0.223961    0.246811    0.817861
# min      0.084595   -0.027355    0.093054    0.095571    1.000000
# 25%      0.343922    0.261674    0.342785    0.376390    1.000000
# 50%      0.595929    0.356967    0.503191    0.728667    2.000000
# 75%      0.760409    0.736215    0.726713    0.841539    3.000000
# max      1.144656    1.020722    1.057730    1.077222    3.000000

# %%
X = dataset.drop(columns='V5').values
Y = dataset[['V5']].values.ravel()

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, stratify=Y, random_state=42)

# %% [markdown]
# ## SKLearn

# %%
from sklearn.neural_network import MLPClassifier

# %%
clf1 = MLPClassifier(hidden_layer_sizes=(2), random_state=42, alpha=0, beta_1=0, beta_2=0, momentum=0, power_t=0, nesterovs_momentum=False)
clf1.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# MLPClassifier(activation='relu', alpha=0, batch_size='auto', beta_1=0, beta_2=0,
#               early_stopping=False, epsilon=1e-08, hidden_layer_sizes=2,
#               learning_rate='constant', learning_rate_init=0.001, max_fun=15000,
#               max_iter=200, momentum=0, n_iter_no_change=10,
#               nesterovs_momentum=False, power_t=0, random_state=42,
#               shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#               verbose=False, warm_start=False)

# %%
print('Remp: ', (1 - clf1.score(X_train, Y_train)), ' / Rest: ', (1 - clf1.score(X_test, Y_test)))
print('Remp - Rest: ', (1 - clf1.score(X_train, Y_train)) - (1 - clf1.score(X_test, Y_test)))
# Out:
# Remp:  0.56  / Rest:  0.56
# Remp - Rest:  0.0

# %%
clf2 = MLPClassifier(hidden_layer_sizes=(2), learning_rate_init=0.1, random_state=42, alpha=0, beta_1=0, beta_2=0, momentum=0, power_t=0, nesterovs_momentum=False)
clf2.fit(X_train, Y_train)
# Out:
# MLPClassifier(activation='relu', alpha=0, batch_size='auto', beta_1=0, beta_2=0,
#               early_stopping=False, epsilon=1e-08, hidden_layer_sizes=2,
#               learning_rate='constant', learning_rate_init=0.1, max_fun=15000,
#               max_iter=200, momentum=0, n_iter_no_change=10,
#               nesterovs_momentum=False, power_t=0, random_state=42,
#               shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#               verbose=False, warm_start=False)

# %%
print('Remp: ', (1 - clf2.score(X_train, Y_train)), ' / Rest: ', (1 - clf2.score(X_test, Y_test)))
print('Remp - Rest: ', (1 - clf2.score(X_train, Y_train)) - (1 - clf2.score(X_test, Y_test)))
# Out:
# Remp:  0.008888888888888835  / Rest:  0.013333333333333308
# Remp - Rest:  -0.004444444444444473
